# %% [markdown]
# # hi

# %%
import pandas as pd

# %%
df = pd.read_csv('../student_data.csv')

# %%
print(df.head())
print(df.shape)
print(df.describe)
# Out:
#    hours_studied  hours_slept  exam_score
# 0            4.4          7.0        19.9
# 1            9.6          4.9        32.6
# 2            7.6          4.3        27.8
# 3            6.4          8.7        34.6
# 4            2.4          8.8        22.6
# (30, 3)
# <bound method NDFrame.describe of     hours_studied  hours_slept  exam_score
# 0             4.4          7.0        19.9
# 1             9.6          4.9        32.6
# 2             7.6          4.3        27.8
# 3             6.4          8.7        34.6
# 4             2.4          8.8        22.6
# 5             2.4          8.0        15.4
# 6             1.5          5.5        16.4
# 7             8.8          4.5        31.2
# 8             6.4          7.4        27.9
# 9             7.4          6.2        32.7
# 10            1.2          4.6        16.6
# 11            9.7          6.5        39.9
# 12            8.5          4.2        28.7
# 13            2.9          8.5        21.6
# 14            2.6          5.3        18.9
# 15            2.7          7.3        23.3
# 16            3.7          5.6        19.6
# 17            5.7          6.6        26.7
# 18            4.9          6.7        22.0
# 19            3.6          4.9        16.4
# 20            6.5          8.8        34.3
# 21            2.3          7.9        24.2
# 22            3.6          8.7        24.3
# 23            4.3          8.5        28.9
# 24            5.1          7.0        27.2
# 25            8.1          8.6        33.6
# 26            2.8          4.4        18.4
# 27            5.6          5.0        29.7
# 28            6.3          4.2        25.8
# 29            1.4          5.6        20.0>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   hours_studied  30 non-null     float64
#  1   hours_slept    30 non-null     float64
#  2   exam_score     30 non-null     float64
# dtypes: float64(3)
# memory usage: 852.0 bytes

# %%
df.dtypes
# Out:
# hours_studied    float64
# hours_slept      float64
# exam_score       float64
# dtype: object

# %%
print(df.isnull().sum())          # count of missing values per column
# Out:
# hours_studied    0
# hours_slept      0
# exam_score       0
# dtype: int64

# %%
print(df.isnull().mean() * 100)   # percentage missing per column
# Out:
# hours_studied    0.0
# hours_slept      0.0
# exam_score       0.0
# dtype: float64

# %%
df.describe()
# Out:
#        hours_studied  hours_slept  exam_score
# count      30.000000    30.000000   30.000000
# mean        4.946667     6.473333   25.373333
# std         2.545684     1.638109    6.441939
# min         1.200000     4.200000   15.400000
# 25%         2.725000     4.925000   19.925000
# 50%         4.650000     6.550000   25.050000
# 75%         6.475000     7.975000   29.500000
# max         9.700000     8.800000   39.900000
