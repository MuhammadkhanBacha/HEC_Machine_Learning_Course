# %% [markdown]
# # Going to learn basic code in Panda
# ## Starting with importing Panda

# %%
import pandas as pd

# %% [markdown]
# ## Loading CSV

# %%
df = pd.read_csv('../student_data.csv')

# %%
print(df.head())
# Out:
#    hours_studied  hours_slept  exam_score
# 0            4.4          7.0        19.9
# 1            9.6          4.9        32.6
# 2            7.6          4.3        27.8
# 3            6.4          8.7        34.6
# 4            2.4          8.8        22.6

# %%
print(df.shape)
# Out:
# (30, 3)

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of     hours_studied  hours_slept  exam_score
# 0             4.4          7.0        19.9
# 1             9.6          4.9        32.6
# 2             7.6          4.3        27.8
# 3             6.4          8.7        34.6
# 4             2.4          8.8        22.6
# 5             2.4          8.0        15.4
# 6             1.5          5.5        16.4
# 7             8.8          4.5        31.2
# 8             6.4          7.4        27.9
# 9             7.4          6.2        32.7
# 10            1.2          4.6        16.6
# 11            9.7          6.5        39.9
# 12            8.5          4.2        28.7
# 13            2.9          8.5        21.6
# 14            2.6          5.3        18.9
# 15            2.7          7.3        23.3
# 16            3.7          5.6        19.6
# 17            5.7          6.6        26.7
# 18            4.9          6.7        22.0
# 19            3.6          4.9        16.4
# ...

# %%
def check_age(x):
    if x > 18:
        return 'Adult'
    else:
        return 'Minor'

# %%
df['status'] = df['age'].apply(check_age)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\Coursera_MachineLearning_UniversityOfWashington\myenv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df['status']
# Out:
# 0    Adult
# 1    Adult
# 2    Adult
# 3    Adult
# 4    Adult
# 5    Adult
# 6    Adult
# Name: status, dtype: str

# %%
df
# Out:
#   First Name Last Name        Country  age status
# 0        Bob     Smith  United States   24  Adult
# 1      Alice  Williams         Canada   23  Adult
# 2    Malcolm      Jone        England   22  Adult
# 3      Felix     Brown            USA   23  Adult
# 4       Alex    Cooper         Poland   23  Adult
# 5        Tod  Campbell  United States   22  Adult
# 6      Derek      Ward    Switzerland   25  Adult
