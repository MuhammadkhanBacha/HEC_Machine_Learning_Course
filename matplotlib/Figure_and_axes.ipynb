# %%
import matplotlib.pyplot as plt

# OO interface (preferred)
fig, ax = plt.subplots()
ax.plot([1, 2, 3], [4, 5, 6])
ax.set_title("Hardcoded data")
plt.show()

# %%
# pyplot interface (equivalent quick version)
plt.plot([1, 2, 3], [4, 5, 6])
plt.show()
